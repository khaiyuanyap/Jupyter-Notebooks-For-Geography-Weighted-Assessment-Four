# %% [markdown]
# <a href="https://colab.research.google.com/github/khaiyuanyap/Jupyter-Notebooks-For-Geography-Weighted-Assessment-Four/blob/main/Pure_Primary_Data_Analysis_On_Student_Connectivity_(Classified_By_Student_Residence_DGP_Zone).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pure Primary Data Analysis On Student Connectivity (Classified By Student Residence DGP Zone)
#
# ## Sources
#
# Research On Public Transport Connectivity For Students Through Interview And Surveys And Analysis
#
# © 2024 by Naomi Su, Trixie Koh, Hu Yan, Isaac Tiang and Khai Yuan is licensed under Creative Commons Attribution 4.0 International
#
# ---
#
#
# Development Guide Plan: Planning Zones
#
# Urban Redevelopment Authority (URA) @ onemap.gov.sg
# https://www.onemap.gov.sg/apidocs/apidocs/
#
# Last access: July 24, 2024
#
# Date created: 2019
#
# Licence: [Singapore Open Data Licence version 1.0](https://www.onemap.gov.sg/legal/opendatalicence.html)
#
# © 2024 Open Government Products, Government Technology Agency of Singapore

# %%
# %matplotlib inline

# %%
# Import libraries
import gspread
from google.colab import auth
from oauth2client.client import GoogleCredentials
from google.auth import default
from google.colab import data_table
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_table.enable_dataframe_formatter()

# %% [markdown]
# # Interview And Survey Results

# %%
# Authenticate and create a client
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)


spreadsheetName = "How well-connected is Singapore's public transport system for students? (Responses)"
sheetName = "Clean Data"  # <--- please set the sheet name here.
spreadsheet = gc.open(spreadsheetName)
sheet = spreadsheet.worksheet(sheetName)

data = sheet.get_all_values()
print(data)
# Out:
# [['Timestamp', 'Email address', 'What level of education are you currently at?', 'Which school are you currently studying in?', 'What time do you normally end school? (Non-CCA days) ', 'What time do you normally end school? (CCA days)', 'DGP Zone (https://www.ura.gov.sg/maps/?service=MP)', 'Which mode(s) of transport do you take to school?', 'Does your journey to school require more than one mode of transport?', 'Average Commuting Duration', 'How many different routes of transport can you take to commute to school?', 'Average non-peak hour waiting time (5:30am to 7:45am, 9:00am to 5:00pm)', 'Average peak hour waiting time (7:45am to 9:00am, 5:00pm to 8:00pm)', 'How many bus stops are a short walking distance (~5 to 10 mins) from your school?', 'On a scale of 1-10, how effective do you think the transport system is in serving your needs?', 'Please specify your reason:', 'On a scale of 1-10, how satisfied are you with the connectivity of the Singapore transport system?', 'Please specify your reason:', 'How do you think the Singapore transport system can be improved for your benefit? (e.g. more modes of public transport available nearer to your school)'], ['12/06/2024 22:25:35', 'joeyshi26@gmail.com', 'JC/Polytechnic/ITE', 'ANGLO-CHINESE JUNIOR COLLEGE', '3:00\u202fpm', '8:00\u202fpm', 'Bukit Batok', 'Mass Rapid Transit', 'Yes', '1:00:00', '3', '0:05:00', '0:03:00', '4', '9', 'I can get to places quickly.', '9', 'There are many routes to go to the same place.', 'There can be bus stops placed right outside my school so that it is convenient on rainy days'], ['12/06/2024 22:53:58', 'theliuyunfeng2007@gmail.com', 'JC/Polytechnic/ITE', 'RIVER VALLEY HIGH SCHOOL', '5:30\u202fpm', '6:00\u202fpm', 'Juong East', 'Private Car', 'No', '0:20:00', '3', '0:10:00', '0:05:00', '5 or more', '8', "Don't be nosy, but if you want to know, it's because it's cheap and fast.", '8', 'It connects the various places of SG well', 'Cheaper services'], ['13/06/2024 10:54:50', 'triciaczl21@gmail.com', 'JC/Polytechnic/ITE', 'RAFFLES INSTITUTION', '3:00\u202fpm', '7:00\u202fpm', 'Bishan', 'Mass Rapid Transit, Private Car', 'No', '1:00:00', '2', '0:05:00', '0:03:00', '2', '8', 'The transport system is effective as it is efficient in sending me to various locations and it is clean.', '9', 'There are many MRT lines and MRT stops. Furthermore, there are always plans of expansion or creation of new MRT lines', 'I think trains can come more frequently during peak hours'], ['10/06/2024 15:58:34', 'ferlynaw2013@gmail.com', 'Primary', 'GONGSHANG PRIMARY SCHOOL', '1:30\u202fpm', '4.30 PM', 'Tampines', 'Bus', 'No', '0:12:30', '1', '0:20:00', '0:15:00', '1', '5', 'It is helping me', '10', 'Good service ', 'Shorter waiting time for the bus'], ['10/06/2024 19:52:40', 'isaiah.soojq@gmail.com', 'Primary', 'NAN HUA HIGH SCHOOL', '1:30\u202fpm', '4:30\u202fpm', 'Clementi', 'Private Car', 'No', '0:08:00', '2', '0:00:00', '', '1', '7', 'i think its alright', '9', 'mrt and bus stations are everywhere in singapore', 'maybe lessen the wait time'], ['10/06/2024 20:02:06', 'jaydentan101012@gmail.com', 'Primary', "ST. ANTHONY'S PRIMARY SCHOOL", '1:30\u202fpm', '4:00\u202fpm', 'Choa Chu Kang', 'Bus, Private Car', 'No', '0:15:00', '1', '0:15:00', '0:15:00', '2', '8', "It's effective but sometimes the bus will take long to arrive but other than that the transport is good", '8', 'The Singapore transport system is safe and clean', 'Buses and mrts will take faster to arrive '], ['10/06/2024 20:06:30', 'kyshwenfoo@gmail.com', 'Primary', "ST. ANTHONY'S PRIMARY SCHOOL", '1:30\u202fpm', '5:00\u202fpm', 'Tengah', 'Private Car', 'No', '0:10:00', '3', '0:15:00', '0:05:00', '3', '8', 'convenient ', '9', 'convenient ', 'Add more bus stops'], ['10/06/2024 20:40:09', 'jerome.sagaram@gmail.com', 'Primary', "ST. ANTHONY'S PRIMARY SCHOOL", '1:30\u202fpm', '5:00\u202fpm', 'Bukit Panjang', 'Bus, Private Car', 'No', '0:30:00', '3', '0:08:00', '0:05:00', '5 or more', '8', 'There are bus stops everywhere', '9' ...

# %%
import pandas as pd

# Convert the data from the Google Sheet into a Pandas DataFrame
df_ias = pd.DataFrame(data[1:], columns=data[0])
df_ias = df_ias.drop('Timestamp', axis=1)


# Print the DataFrame
df_ias
# Out:
#                             Email address  \
# 0                     joeyshi26@gmail.com
# 1             theliuyunfeng2007@gmail.com
# 2                   triciaczl21@gmail.com
# 3                  ferlynaw2013@gmail.com
# 4                  isaiah.soojq@gmail.com
# 5               jaydentan101012@gmail.com
# 6                    kyshwenfoo@gmail.com
# 7                jerome.sagaram@gmail.com
# 8                noahpsg2742012@gmail.com
# 9                  denzelquek20@gmail.com
# 10                      oc30nzy@gmail.com
# 11                     rayenkok@gmail.com
# 12                   leannextan@gmail.com
# 13  nh26_lynette_lek_rui_ying@nhhs.edu.sg
# 14                      jrchuah@gmail.com
# 15                    mp4aqilah@gmail.com
# 16                     sohyumin@gmail.com
# 17                    asherztan@gmail.com
# 18             231425e@student.hci.edu.sg
# 19     nh25_cara_goh_shuen_yi@nhhs.edu.sg
# 20                    aleth.tym@gmail.com
# 21      ananya_cinderella@students.edu.sg
# 22                    erinchiow@gmail.com
# 23       nh25_kaeden_sim_wing@nhhs.edu.sg
# 24             gwendolyn.guntur@gmail.com
# 25     jordan_ong_yong_en@students.edu.sg
# 26       nh27_daven_chong_jun@nhhs.edu.sg
# 27                 audrey.y.tan@gmail.com
# 28           soh_chia_hee@students.edu.sg
# 29                   yawxychloe@gmail.com
# 30       nh26_trixie_koh_yuxi@nhhs.edu.sg
# 31                  noelleongyx@gmail.com
# 32           nh26_hu_wenxin_1@nhhs.edu.sg
# 33                    huy4n0119@gmail.com
# 34          nh27_kuay_yu_hang@nhhs.edu.sg
# 35                nh26_hu_yan@nhhs.edu.sg
# 36                     ptan4703@gmail.com
# 37             xuehaiwuya122333@gmail.com
# 38          nh26_chan_yantong@nhhs.edu.sg
# 39    nh26_magnus_loh_you_jun@nhhs.edu.sg
# 40           nh27_ashlie_khor@nhhs.edu.sg
# 41  nh26_jayvyn_lim_jing_yuan@nhhs.edu.sg
# 42    nh27_gideon_sim_wen_tin@nhhs.edu.sg
# 43                carolinesyluo@gmail.com
# 44              claris.seah0206@gmail.com
# 45                    yekatelyn@gmail.com
# 46              carrielimleryee@gmail.com
# 47                     ridghule@gmail.com
# 48               kaylaandreyana@gmail.com
# 49        maia_erika_leow@students.edu.sg
# 50              aishwaryalingem@gmail.com
# 51                   ashteo0505@gmail.com
# 52   shauna_keshini_doyle@students.edu.sg
#
#    What level of education are you currently at?  \
# 0                             JC/Polytechnic/ITE
# 1                             JC/Polytechnic/ITE
# 2                             JC/Polytechnic/ITE
# 3                                        Primary
# 4                                        Primary
# 5                                        Primary
# 6                                        Primary
# 7                                        Primary
# 8                                        Primary
# 9                                        Primary
# 10                                       Primary
# 11                                       Primary
# 12                                     Secondary
# 13                                     Secondary
# 14                                     Secondary
# 15                                     Secondary
# 16                                     Secondary
# 17                                     Secondary
# 18                                     Secondary
# 19                                     Secondary
# 20                                     Secondary
# 21                                     Secondary
# 22                                     Secondary
# 23                                     Secondary
# 24                                     Secondary
# 25                                     Secondary
# 26                                     Secondary
# 27                                     Secondary
# 28                                     Secondary
# 29                                     Secondary
# 30                                     Secondary
# 31                                     Secondary
# 32                                     Secondary
# 33                                     Secondary
# 34                                     Secondary
# 35                                     Secondary
# 36                                     Secondary
# 37                                     Secondary
# 38                                     Secondary
# 39                                     Secondary
# 40                                     Secondary
# 41                                     Secondary
# 42                                     Secondary
# 43                                     Secondary
# 44                                     Secondary
# 45                                     Secondary
# 46                                     Secondary
# 47                                     Secondary
# 48                                     Secondary
# 49                                     Secondary
# 50                                     Secondary
# 51                                     Secondary
# 52                                     Secondary
#
#    Which school are you currently studying in?  \
# 0                 ANGLO-CHINESE JUNIOR COLLEGE
# 1                     RIVER VALLEY HIGH SCHOOL
# 2                          RAFFLES INSTITUTION
# 3                     GONGSHANG PRIMARY SCHOOL
# 4                          NAN HUA HIGH SCHOOL
# 5                 ST. ANTHONY'S PRIMARY SCHOOL
# 6                 ST. ANTHONY'S PRIMARY SCHOOL
# 7                 ST. ANTHONY'S PRIMARY SCHOOL
# 8                       NAN HUA PRIMARY SCHOOL
# 9                       NAN HUA PRIMARY SCHOOL
# 10                      NAN HUA PRIMARY SCHOOL
# 11                      NAN HUA PRIMARY SCHOOL
# 12               COMMONWEALTH SECONDARY SCHOOL
# 13                         NAN HUA HIGH SCHOOL
# 14               COMMONWEALTH SECONDARY SCHOOL
# 15                  HILLGROVE SECONDARY SCHOOL
# 16                      FUHUA SECONDARY SCHOOL
# 17                    ST. JOSEPH'S INSTITUTION
# 18                       HWA CHONG INSTITUTION
# 19                         NAN HUA HIGH SCHOOL
# 20                          DUNMAN HIGH SCHOOL
# 21                     NATIONAL JUNIOR COLLEGE
# 22                          DUNMAN HIGH SCHOOL
# 23                         NAN HUA HIGH SCHOOL
# 24                          DUNMAN HIGH SCHOOL
# 25                      YUHUA SECONDARY SCHOOL
# 26                         NAN HUA HIGH SCHOOL
# 27                TANJONG KATONG GIRLS' SCHOOL
# 28                     NATIONAL JUNIOR COLLEGE
# 29               CEDAR GIRLS' SECONDARY SCHOOL
# 30                         NAN HUA HIGH SCHOOL
# 31                         NAN HUA HIGH SCHOOL
# 32                         NAN HUA HIGH SCHOOL
# 33                         NAN HUA HIGH SCHOOL
# 34                         NAN HUA HIGH SCHOOL
# 35                         NAN HUA HIGH SCHOOL
# 36              CLEMENTI TOWN SECONDARY SCHOOL
# 37                         NAN HUA HIGH SCHOOL
# 38                         NAN HUA HIGH SCHOOL
# 39                         NAN HUA HIGH SCHOOL
# 40                         NAN HUA HIGH SCHOOL
# 41                         NAN HUA HIGH SCHOOL
# 42                         NAN HUA HIGH SCHOOL
# 43                         NAN HUA HIGH SCHOOL
# 44                  NANYANG GIRLS' HIGH SCHOOL
# 45                    DUNEARN SECONDARY SCHOOL
# 46                TANJONG KATONG GIRLS' SCHOOL
# 47                TANJONG KATONG GIRLS' SCHOOL
# 48                TANJONG KATONG GIRLS' SCHOOL
# 49                TANJONG KATONG GIRLS' SCHOOL
# 50                TANJONG KATONG GIRLS' SCHOOL
# 51                TANJONG KATONG GIRLS' SCHOOL
# 52                TANJONG KATONG GIRLS' SCHOOL
#
#    What time do you normally end school? (Non-CCA days)   \
# 0                                             3:00 pm
# 1                                             5:30 pm
# 2                                             3:00 pm
# 3                                             1:30 pm
# 4                                             1:30 pm
# 5                                             1:30 pm
# 6                                             1:30 pm
# 7                                             1:30 pm
# 8                                             1:30 pm
# 9                                             1:30 pm
# 10                                            1:30 pm
# 11                                            1:30 pm
# 12                                            3:00 pm
# 13                                            2:10 pm
# 14                                            3:00 pm
# 15                                            3:00 pm
# 16                                            2:15 pm
# 17                                           12:00 pm
# 18                                            1:30 pm
# 19                                            2:35 pm
# 20                                            3:00 pm
# 21                                            2:00 pm
# 22                                            2:30 pm
# 23                                            2:35 pm
# 24                                            3:00 pm
# 25                                            3:00 pm
# 26                                            2:00 pm
# 27                                            2:15 pm
# 28                                            2:00 pm
# 29                                            2:30 pm
# 30                                            2:00 pm
# 31                                            2:10 pm
# 32                                            2:35 pm
# 33                                            2:30 pm
# 34                                            2:40 pm
# 35                                            2:30 pm
# 36                                            3:00 pm
# 37                                            2:15 pm
# 38                                            2:00 pm
# 39                                            2:00 pm
# 40                                            2:10 pm
# 41                                            2:00 pm
# 42                                            2:00 pm
# 43                                            2:30 pm
# 44                                            3:00 pm
# 45                                            3:15 pm
# 46                                            2:30 pm
# 47                                            2:30 pm
# 48                                            2:30 pm
# 49                                            2:30 pm
# 50                                            2:30 pm
# 51                                            2:30 pm
# 52                                            2:30 pm
#
#    What time do you normally end school? (CCA days)  \
# 0                                           8:00 pm
# 1                                           6:00 pm
# 2                                           7:00 pm
# 3                                           4.30 PM
# 4                                           4:30 pm
# 5                                           4:00 pm
# 6                                           5:00 pm
# 7                                           5:00 pm
# 8                                           5:30 pm
# 9                                           5:30 pm
# 10                                          4:30 pm
# 11                                          5:30 pm
# 12                                          5:15 pm
# 13                                          5:00 pm
# 14                                          6:00 pm
# 15                                          5:00 pm
# 16                                          6:00 pm
# 17                                          5:30 pm
# 18                                          5:00 pm
# 19                                          6:00 pm
# 20                                          6:30 pm
# 21                                          6:00 pm
# 22                                          6:30 pm
# 23                                          5:30 pm
# 24                                          6:30 pm
# 25                                          6:00 pm
# 26                                          5:00 pm
# 27                                          6:00 pm
# 28                                          6:00 pm
# 29                                          5:00 pm
# 30                                          5:30 pm
# 31                                          6:00 pm
# 32                                          5:30 pm
# 33                                          5:30 pm
# 34                                          5:30 pm
# 35                                          5:30 pm
# 36                                          6:00 pm
# 37                                          6:00 pm
# 38                                          6:00 pm
# 39                                          5:00 pm
# 40                                          5:00 pm
# 41                                          5.30 PM
# 42                                          5:30 am
# 43                                          6:00 pm
# 44                                          6:00 pm
# 45                                          6:00 pm
# 46                                          6:00 pm
# 47                                          6:00 pm
# 48                                          5:45 pm
# 49                                          5:45 pm
# 50                                          5:45 pm
# 51                                          6:00 pm
# 52                                          6:00 pm
#
#    DGP Zone (https://www.ura.gov.sg/maps/?service=MP)  \
# 0                                         Bukit Batok
# 1                                          Juong East
# 2                                              Bishan
# 3                                            Tampines
# 4                                            Clementi
# 5                                       Choa Chu Kang
# 6                                              Tengah
# 7                                       Bukit Panjang
# 8                                         Bukit Timah
# 9                                         Queenstown
# 10                                           Clementi
# 11                                        Jurong West
# 12                                        Jurong East
# 13                                      Choa Chu Kang
# 14                                        Jurong East
# 15                                        Bukit Batok
# 16                                           Clementi
# 17                                        Jurong West
# 18                                            Hougang
# 19                                           Clementi
# 20                                            Geylang
# 21                                      Bukit Panjang
# 22                                            Outram
# 23                                      Bukit Panjang
# 24                                        Bukit Merah
# 25                                           Clementi
# 26                                          Woodlands
# 27                                           Clementi
# 28                                      Bukit Panjang
# 29                                        Bukit Merah
# 30                                      Bukit Panjang
# 31                                      Choa Chu Kang
# 32                                         Queenstown
# 33                                        Bukit Batok
# 34                                        Bukit Batok
# 35                                        Bukit Batok
# 36                                        Jurong East
# 37                                           Clementi
# 38                                           Clementi
# 39                                           Clementi
# 40                                           Clementi
# 41                                           Boon Lay
# 42                                           Clementi
# 43                                           Clementi
# 44                                           Clementi
# 45                                           Clementi
# 46                                        Jurong East
# 47                                             Siglap
# 48                                      Marine Parade
# 49                                              Bedok
# 50                                           Tampines
# 51                                          Toa Payoh
# 52                                          Pasir Ris
#
#    Which mode(s) of transport do you take to school?  \
# 0                                 Mass Rapid Transit
# 1                                        Private Car
# 2                    Mass Rapid Transit, Private Car
# 3                                                Bus
# 4                                        Private Car
# 5                                   Bus, Private Car
# 6                                        Private Car
# 7                                   Bus, Private Car
# 8                                        Private Car
# 9                                   Bus, Private Car
# 10                                  Bus, Private Car
# 11                           Bus, Mass Rapid Transit
# 12                                               Bus
# 13                                Mass Rapid Transit
# 14                                               Bus
# 15                                               Bus
# 16                                               Bus
# 17                   Mass Rapid Transit, Private Car
# 18                                               Car
# 19                                       Private Car
# 20              Bus, Mass Rapid Transit, Private Car
# 21                           Bus, Mass Rapid Transit
# 22                                               Bus
# 23                                  Bus, Private Car
# 24                                               Bus
# 25                                Mass Rapid Transit
# 26              Bus, Mass Rapid Transit, Private Car
# 27                                  Bus, Private Car
# 28              Bus, Mass Rapid Transit, Private Car
# 29                           Bus, Mass Rapid Transit
# 30              Bus, Mass Rapid Transit, Private Car
# 31                                       Private Car
# 32                           Bus, Mass Rapid Transit
# 33                                  Bus, Private Car
# 34                           Bus, Mass Rapid Transit
# 35                                  Bus, Private Car
# 36                                               Bus
# 37                                              Walk
# 38                                       Private Car
# 39                                               Bus
# 40                                       Private Car
# 41                           Bus, Mass Rapid Transit
# 42                                      Bus, Walking
# 43                                       Private Car
# 44                                  Bus, Private Car
# 45                                               Bus
# 46                                  Bus, Private Car
# 47                                       Private Car
# 48                                       Private Car
# 49              Bus, Mass Rapid Transit, Private Car
# 50                                               Bus
# 51                                  Bus, Private Car
# 52                                       Private Car
#
#    Does your journey to school require more than one mode of transport?  \
# 0                                                 Yes
# 1                                                  No
# 2                                                  No
# 3                                                  No
# 4                                                  No
# 5                                                  No
# 6                                                  No
# 7                                                  No
# 8                                                  No
# 9                                                  No
# 10                                                 No
# 11                                                Yes
# 12                                                 No
# 13                                                Yes
# 14                                                 No
# 15                                                 No
# 16                                                 No
# 17                                                 No
# 18                                                 No
# 19                                                 No
# 20                                                 No
# 21                                                 No
# 22                                                 No
# 23                                                 No
# 24                                                 No
# 25                                                 No
# 26                                                Yes
# 27                                                 No
# 28                                                 No
# 29                                                Yes
# 30                                                Yes
# 31                                                 No
# 32                                                Yes
# 33                                                 No
# 34                                                Yes
# 35                                                 No
# 36                                                 No
# 37                                                 No
# 38                                                 No
# 39                                                 No
# 40                                                 No
# 41                                                Yes
# 42                                                 No
# 43                                                 No
# 44                                                Yes
# 45                                                 No
# 46                                                 No
# 47                                                 No
# 48                                                 No
# 49                                                 No
# 50                                                Yes
# 51                                                 No
# 52                                                 No
#
#    Average Commuting Duration  \
# 0                     1:00:00
# 1                     0:20:00
# 2                     1:00:00
# 3                     0:12:30
# 4                     0:08:00
# 5                     0:15:00
# 6                     0:10:00
# 7                     0:30:00
# 8                     0:15:00
# 9                     0:17:30
# 10                    0:13:00
# 11                    0:30:00
# 12                    0:15:00
# 13                    0:50:00
# 14                    0:20:00
# 15                    0:07:00
# 16                    0:40:00
# 17                    0:30:00
# 18                    0:20:00
# 19                    0:10:00
# 20                    0:30:00
# 21                    0:45:00
# 22                    0:10:00
# 23                    0:45:00
# 24                    0:40:00
# 25                    0:30:00
# 26                    0:30:00
# 27                    1:00:00
# 28                    0:25:00
# 29                    0:40:00
# 30                    1:00:00
# 31                    0:20:00
# 32                    0:30:00
# 33                    0:45:00
# 34                    0:50:00
# 35                    0:45:00
# 36                    0:30:00
# 37                    0:03:00
# 38                    0:10:00
# 39                    0:10:00
# 40                    0:10:00
# 41                    0:30:00
# 42                    0:08:30
# 43                    0:05:00
# 44                    0:35:00
# 45                    0:30:00
# 46                    0:30:00
# 47                    0:15:00
# 48                    0:12:30
# 49                    1:00:00
# 50                    2:07:15
# 51                    0:30:00
# 52                    0:30:00
#
#    How many different routes of transport can you take to commute to school?  \
# 0                                                   3
# 1                                                   3
# 2                                                   2
# 3                                                   1
# 4                                                   2
# 5                                                   1
# 6                                                   3
# 7                                                   3
# 8                                                   3
# 9                                                   1
# 10                                                  2
# 11                                                  2
# 12                                                  3
# 13                                                  2
# 14                                                  2
# 15                                                  2
# 16                                          5 or more
# 17                                                  1
# 18                                                  2
# 19                                                  3
# 20                                                  4
# 21                                                  2
# 22                                                  2
# 23                                                  2
# 24                                                  1
# 25                                                  1
# 26                                                  3
# 27                                                  2
# 28                                                  2
# 29                                                  3
# 30                                                  3
# 31                                                  2
# 32                                                  2
# 33                                                  2
# 34                                                  2
# 35                                                  3
# 36                                                  1
# 37                                                  1
# 38                                                  2
# 39                                          5 or more
# 40                                                  1
# 41                                                  2
# 42                                                  2
# 43                                                  2
# 44                                                  2
# 45                                                  1
# 46                                                  3
# 47                                                  1
# 48                                                  1
# 49                                                  3
# 50                                                  1
# 51                                                  2
# 52                                                  1
#
#    Average non-peak hour waiting time (5:30am to 7:45am, 9:00am to 5:00pm)  \
# 0                                             0:05:00
# 1                                             0:10:00
# 2                                             0:05:00
# 3                                             0:20:00
# 4                                             0:00:00
# 5                                             0:15:00
# 6                                             0:15:00
# 7                                             0:08:00
# 8                                             0:10:00
# 9                                             0:07:00
# 10                                            0:05:00
# 11                                            0:05:00
# 12                                            0:10:00
# 13                                            0:05:00
# 14                                            0:15:00
# 15                                            0:07:30
# 16                                            0:08:00
# 17                                                 NA
# 18                                            0:03:00
# 19                                            0:15:00
# 20                                            0:05:00
# 21                                            0:06:00
# 22              depending on the waiting time for bus
# 23                                            0:10:00
# 24                                            0:10:00
# 25                                            0:02:30
# 26                                            0:05:00
# 27                                            0:17:30
# 28                                            0:10:00
# 29                                            0:07:30
# 30                                            0:07:30
# 31                                            0:00:00
# 32                                            0:07:30
# 33                                            0:15:00
# 34                                            0:06:30
# 35                                            0:10:00
# 36                                            0:07:30
# 37                                            0:10:00
# 38                                            0:04:30
# 39                                            0:07:00
# 40                                            0:06:00
# 41                                            0:07:20
# 42                                            0:08:30
# 43                                            0:00:00
# 44                                            0:10:00
# 45                                            0:10:00
# 46                                            0:06:30
# 47                                            0:05:00
# 48                                            0:05:00
# 49                                            0:15:00
# 50                                            0:07:30
# 51                                            0:04:00
# 52                                            0:05:00
#
#    Average peak hour waiting time (7:45am to 9:00am, 5:00pm to 8:00pm)  \
# 0                                             0:03:00
# 1                                             0:05:00
# 2                                             0:03:00
# 3                                             0:15:00
# 4
# 5                                             0:15:00
# 6                                             0:05:00
# 7                                             0:05:00
# 8                                             0:20:00
# 9                                             0:11:30
# 10                                            0:15:00
# 11                                            0:05:00
# 12                                            0:07:00
# 13                                            0:06:00
# 14                                            0:15:00
# 15                                            0:08:00
# 16                                            0:08:00
# 17                                            0:04:00
# 18                                            0:05:00
# 19                                            0:20:00
# 20                                            0:01:00
# 21                                            0:01:30
# 22
# 23                                            0:10:00
# 24                                           00:10:00
# 25                                            0:01:30
# 26                                            0:08:00
# 27                                            0:10:00
# 28                                            0:10:00
# 29                                            0:04:00
# 30                                            0:10:00
# 31                                           00:00:00
# 32                                            0:10:00
# 33                                            0:06:00
# 34                                            0:10:00
# 35                                            0:07:00
# 36                                            0:17:30
# 37                                            0:05:00
# 38                                            0:06:30
# 39                                            0:07:00
# 40                                            0:10:00
# 41                                            0:07:30
# 42                                            0:12:30
# 43
# 44                                            0:15:00
# 45                                            0:15:00
# 46                                            0:15:00
# 47                                            0:10:00
# 48                                            0:10:00
# 49                                            0:20:00
# 50                                            0:13:30
# 51                                            0:08:00
# 52                                            0:05:00
#
#    How many bus stops are a short walking distance (~5 to 10 mins) from your school?  \
# 0                                                   4
# 1                                           5 or more
# 2                                                   2
# 3                                                   1
# 4                                                   1
# 5                                                   2
# 6                                                   3
# 7                                           5 or more
# 8                                                   3
# 9                                                   3
# 10                                                  3
# 11                                                  1
# 12                                          5 or more
# 13                                                  2
# 14                                          5 or more
# 15                                          5 or more
# 16                                                  3
# 17                                                  4
# 18                                                  2
# 19                                                  3
# 20                                                  4
# 21                                          5 or more
# 22                                                  4
# 23                                                  3
# 24                                                  3
# 25                                          5 or more
# 26                                                  3
# 27                                                  4
# 28                                          5 or more
# 29                                                  3
# 30                                                  3
# 31                                                  3
# 32                                                  2
# 33                                                  2
# 34                                                  3
# 35                                                  2
# 36                                                  3
# 37                                          5 or more
# 38                                                  2
# 39                                          5 or more
# 40                                                  3
# 41                                                  4
# 42                                                  3
# 43                                                  2
# 44                                                  4
# 45                                                  4
# 46                                          5 or more
# 47                                          5 or more
# 48                                          5 or more
# 49                                          5 or more
# 50                                          5 or more
# 51                                          5 or more
# 52
#
#    On a scale of 1-10, how effective do you think the transport system is in serving your needs?  \
# 0                                                   9
# 1                                                   8
# 2                                                   8
# 3                                                   5
# 4                                                   7
# 5                                                   8
# 6                                                   8
# 7                                                   8
# 8                                                   5
# 9                                                   7
# 10                                                  7
# 11                                                 10
# 12                                                 10
# 13                                                  9
# 14                                                  9
# 15                                                  9
# 16                                                  7
# 17                                                  8
# 18                                                  7
# 19                                                  8
# 20                                                 10
# 21                                                  8
# 22                                                 10
# 23                                                  8
# 24                                                  8
# 25                                                 10
# 26                                                 10
# 27                                                  8
# 28                                                 10
# 29                                                  8
# 30                                                  8
# 31                                                  9
# 32                                                  8
# 33                                                  8
# 34                                                  7
# 35                                                  8
# 36                                                  7
# 37                                                  4
# 38                                                 10
# 39                                                  8
# 40                                                  8
# 41                                                  8
# 42                                                  8
# 43                                                  6
# 44                                                  8
# ...
# 10                                                  7
# 11                                                 10
# 12                                                 10
# 13                                                 10
# 14                                                  9
# 15                                                 10
# 16                                                 10
# 17                                                  8
# 18                                                  7
# 19                                                  8
# 20                                                 10
# 21                                                  7
# 22                                                 10
# 23                                                  9
# 24                                                  9
# 25                                                  9
# 26                                                  8
# 27                                                  8
# 28                                                 10
# 29                                                 10
# 30                                                  9
# 31                                                  9
# 32                                                  7
# 33                                                  8
# 34                                                 10
# 35                                                  8
# 36                                                  7
# 37                                                 10
# 38                                                  9
# 39                                                  8
# 40                                                  9
# 41                                                 10
# 42                                                  8
# 43                                                  9
# 44                                                  7
# 45                                                  9
# 46                                                  6
# 47                                                  8
# 48                                                  7
# 49                                                  8
# 50                                                  6
# 51                                                  7
# 52                                                  8
#
#                           Please specify your reason:  \
# 0      There are many routes to go to the same place.
# 1           It connects the various places of SG well
# 2   There are many MRT lines and MRT stops. Furthe...
# 3                                       Good service
# 4    mrt and bus stations are everywhere in singapore
# 5    The Singapore transport system is safe and clean
# 6                                         convenient
# 7                                                 Nil
# 8     Most of the time, the buses I take are not late
# 9   Can travel anywhere, just takes awhile which i...
# 10              Sometimes you need to wait quite long
# 11           Do not need to walk long to next station
# 12                              It’s very convenient
# 13  There are many mode of transport for different...
# 14  Although I can go anywhere in Singapore using ...
# 15  i think singapore is overall very well connect...
# 16  Getting from one place to another in Singapore...
# 17  I am able to get everywhere on the island I wa...
# 18                           It's fast and efficient
# 19  majority of the areas in sg are connected by m...
# 20                                         convenient
# 21  some areas are not very well connected e.g. if...
# 22  The transport system allows me to travel aroun...
# 23  I think Singapore has one of the best transpor...
# 24  singapore is quite well connected with transpo...
# 25                              Trains can be faster
# 26        we can change our modes of transport easily
# 27              the waiting times are long for buses
# 28     can go almost everywhere with public transport
# 29  It is really easy to change from mrt to bus an...
# 30  There are many routes I can take to get to a c...
# 31  i am able to travel to different parts in sing...
# 32  All the mrt and bus stations are connected so ...
# 33  I would not have to walk home from school that...
# 34  I feel that the problems can't be solved, peop...
# 35  I would not have to walk very long distances i...
# 36                                      same as above
# 37                               It is well connected
# 38  i think most areas are easy to get to and does...
# 39     It is easy to get around with public transport
# 40  I think that Singapore made the transport syst...
# 41  There are different MRT lines to get me everyw...
# 42  The mrt station is within 1km of me and there ...
# 43  It is easy to get from one place to another, a...
# 44  It might take longer as there are times where ...
# 45  the singapore transport system is very connect...
# 46    think its okay but some areas could be improved
# 47  As to get to MRT Stations, either they are wit...
# 48  I love how convenient everything is, although ...
# 49  Singapore's transport system is efficient, jus...
# 50  sometimes the bus comes later than expected an...
# 51  its very easy to go from one place to another ...
# 52                                          It's fine
#
#    How do you think the Singapore transport system can be improved for your benefit? (e.g. more modes of public transport available nearer to your school)
# 0   There can be bus stops placed right outside my...
# 1                                    Cheaper services
# 2   I think trains can come more frequently during...
# 3                    Shorter waiting time for the bus
# 4                          maybe lessen the wait time
# 5          Buses and mrts will take faster to arrive
# 6                                  Add more bus stops
# 7                        Increase the amount of buses
# 8                                    Have more buses
# 9                      Bus timings should be improved
# 10             Get more buses so shorter waiting time
# 11                                                Nil
# 12                                                Nil
# 13                        More direct buses to school
# 14  The system can be more connected, letting peop...
# 15  more buses because some people might be in a r...
# 16           More evenly spread out timings for buses
# 17                                 SJI is pretty good
# 18  More modes of public transport available neare...
# 19  More bus stops near places w higher influx of ...
# 20                                                nil
# 21             Add more MRT lines to each interchange
# 22                                                nil
# 23                                     Abolish cars.
# 24                           nearer bus and mrt stops
# 25                                       Good enough
# 26                             More seating available
# 27                  more buses to around the country
# 28                                    nil, good as is
# 29                      Nearer bus stops to my school
# 30  There can be more modes of public transport ar...
# 31  i think more bus stops can be built near my sc...
# 32              Higher frequencies of bus/MRT timings
# 33  Shorter waiting times during non peak hours (L...
# 34   More buses for bus stops that can get to schools
# 35  i hope more bus during non-peak hours e.g. bus...
# 36  Analysing the average number of commuters for ...
# 37                Add more public transport services
# 38               more bus services at one bus station
# 39  i hope um buses can start operating ealiee cos...
# 40  I think that we should expand the transport sy...
# 41                      More buses, less waiting time
# 42                                     More bus stops
# 43  If the many modes of public transport could be...
# 44  More MRT lines, buses can come on a more frequ...
# 45  I think the transportations waiting timings ca...
# 46  Shorter waiting times and more modes of transport
# 47  I think the MRT Station could have been placed...
# 48  everything is good now, and I don’t think it c...
# 49  I think that Singapore can add more bus stops ...
# 50  i think there should be more buses catering to...
# 51  more modest of transport available nearer to m...
# 52                     Nothing much really, it's good

# %%
# Extract relevant columns from df_ias
df_ias_by_residence_dgpzone = df_ias[['DGP Zone (https://www.ura.gov.sg/maps/?service=MP)',
                      'Which mode(s) of transport do you take to school?',
                      'Does your journey to school require more than one mode of transport?',
                      'Average Commuting Duration',
                      'How many different routes of transport can you take to commute to school?',
                      'Average non-peak hour waiting time (5:30am to 7:45am, 9:00am to 5:00pm)',
                      'Average peak hour waiting time (7:45am to 9:00am, 5:00pm to 8:00pm)',
                     'How many bus stops are a short walking distance (~5 to 10 mins) from your school?',
                     'On a scale of 1-10, how effective do you think the transport system is in serving your needs?'  ,
                     'On a scale of 1-10, how satisfied are you with the connectivity of the Singapore transport system?'

                      ]]

# Rename columns for clarity
df_ias_by_residence_dgpzone = df_ias_by_residence_dgpzone.rename(columns={
    'DGP Zone (https://www.ura.gov.sg/maps/?service=MP)': 'dgpzone',
    'Which mode(s) of transport do you take to school?': 'transport_modes',
    'Does your journey to school require more than one mode of transport?': 'multi_modal',
    'Average Commuting Duration': 'avg_commute_time',
    'How many different routes of transport can you take to commute to school?': 'num_routes',
    'Average non-peak hour waiting time (5:30am to 7:45am, 9:00am to 5:00pm)': 'avg_nonpeak_wait',
    'Average peak hour waiting time (7:45am to 9:00am, 5:00pm to 8:00pm)': 'avg_peak_wait',
    'How many bus stops are a short walking distance (~5 to 10 mins) from your school?': 'num_bus_stops',
    'On a scale of 1-10, how effective do you think the transport system is in serving your needs?': 'perceived_effectiveness',
    'On a scale of 1-10, how satisfied are you with the connectivity of the Singapore transport system?': 'satisfaction'
})

df_ias_by_residence_dgpzone
# Out:
#           dgpzone                       transport_modes multi_modal  \
# 0     Bukit Batok                    Mass Rapid Transit         Yes
# 1      Juong East                           Private Car          No
# 2          Bishan       Mass Rapid Transit, Private Car          No
# 3        Tampines                                   Bus          No
# 4        Clementi                           Private Car          No
# 5   Choa Chu Kang                      Bus, Private Car          No
# 6          Tengah                           Private Car          No
# 7   Bukit Panjang                      Bus, Private Car          No
# 8     Bukit Timah                           Private Car          No
# 9     Queenstown                       Bus, Private Car          No
# 10       Clementi                      Bus, Private Car          No
# 11    Jurong West               Bus, Mass Rapid Transit         Yes
# 12    Jurong East                                   Bus          No
# 13  Choa Chu Kang                    Mass Rapid Transit         Yes
# 14    Jurong East                                   Bus          No
# 15    Bukit Batok                                   Bus          No
# 16       Clementi                                   Bus          No
# 17    Jurong West       Mass Rapid Transit, Private Car          No
# 18        Hougang                                   Car          No
# 19       Clementi                           Private Car          No
# 20        Geylang  Bus, Mass Rapid Transit, Private Car          No
# 21  Bukit Panjang               Bus, Mass Rapid Transit          No
# 22        Outram                                    Bus          No
# 23  Bukit Panjang                      Bus, Private Car          No
# 24    Bukit Merah                                   Bus          No
# 25       Clementi                    Mass Rapid Transit          No
# 26      Woodlands  Bus, Mass Rapid Transit, Private Car         Yes
# 27       Clementi                      Bus, Private Car          No
# 28  Bukit Panjang  Bus, Mass Rapid Transit, Private Car          No
# 29    Bukit Merah               Bus, Mass Rapid Transit         Yes
# 30  Bukit Panjang  Bus, Mass Rapid Transit, Private Car         Yes
# 31  Choa Chu Kang                           Private Car          No
# 32     Queenstown               Bus, Mass Rapid Transit         Yes
# 33    Bukit Batok                      Bus, Private Car          No
# 34    Bukit Batok               Bus, Mass Rapid Transit         Yes
# 35    Bukit Batok                      Bus, Private Car          No
# 36    Jurong East                                   Bus          No
# 37       Clementi                                  Walk          No
# 38       Clementi                           Private Car          No
# 39       Clementi                                   Bus          No
# 40       Clementi                           Private Car          No
# 41       Boon Lay               Bus, Mass Rapid Transit         Yes
# 42       Clementi                          Bus, Walking          No
# 43       Clementi                           Private Car          No
# 44       Clementi                      Bus, Private Car         Yes
# 45       Clementi                                   Bus          No
# 46    Jurong East                      Bus, Private Car          No
# 47         Siglap                           Private Car          No
# 48  Marine Parade                           Private Car          No
# 49          Bedok  Bus, Mass Rapid Transit, Private Car          No
# 50       Tampines                                   Bus         Yes
# 51      Toa Payoh                      Bus, Private Car          No
# 52      Pasir Ris                           Private Car          No
#
#    avg_commute_time num_routes                       avg_nonpeak_wait  \
# 0           1:00:00          3                                0:05:00
# 1           0:20:00          3                                0:10:00
# 2           1:00:00          2                                0:05:00
# 3           0:12:30          1                                0:20:00
# 4           0:08:00          2                                0:00:00
# 5           0:15:00          1                                0:15:00
# 6           0:10:00          3                                0:15:00
# 7           0:30:00          3                                0:08:00
# 8           0:15:00          3                                0:10:00
# 9           0:17:30          1                                0:07:00
# 10          0:13:00          2                                0:05:00
# 11          0:30:00          2                                0:05:00
# 12          0:15:00          3                                0:10:00
# 13          0:50:00          2                                0:05:00
# 14          0:20:00          2                                0:15:00
# 15          0:07:00          2                                0:07:30
# 16          0:40:00  5 or more                                0:08:00
# 17          0:30:00          1                                     NA
# 18          0:20:00          2                                0:03:00
# 19          0:10:00          3                                0:15:00
# 20          0:30:00          4                                0:05:00
# 21          0:45:00          2                                0:06:00
# 22          0:10:00          2  depending on the waiting time for bus
# 23          0:45:00          2                                0:10:00
# 24          0:40:00          1                                0:10:00
# 25          0:30:00          1                                0:02:30
# 26          0:30:00          3                                0:05:00
# 27          1:00:00          2                                0:17:30
# 28          0:25:00          2                                0:10:00
# 29          0:40:00          3                                0:07:30
# 30          1:00:00          3                                0:07:30
# 31          0:20:00          2                                0:00:00
# 32          0:30:00          2                                0:07:30
# 33          0:45:00          2                                0:15:00
# 34          0:50:00          2                                0:06:30
# 35          0:45:00          3                                0:10:00
# 36          0:30:00          1                                0:07:30
# 37          0:03:00          1                                0:10:00
# 38          0:10:00          2                                0:04:30
# 39          0:10:00  5 or more                                0:07:00
# 40          0:10:00          1                                0:06:00
# 41          0:30:00          2                                0:07:20
# 42          0:08:30          2                                0:08:30
# 43          0:05:00          2                                0:00:00
# 44          0:35:00          2                                0:10:00
# 45          0:30:00          1                                0:10:00
# 46          0:30:00          3                                0:06:30
# 47          0:15:00          1                                0:05:00
# 48          0:12:30          1                                0:05:00
# 49          1:00:00          3                                0:15:00
# 50          2:07:15          1                                0:07:30
# 51          0:30:00          2                                0:04:00
# 52          0:30:00          1                                0:05:00
#
#    avg_peak_wait num_bus_stops perceived_effectiveness satisfaction
# 0        0:03:00             4                       9            9
# 1        0:05:00     5 or more                       8            8
# 2        0:03:00             2                       8            9
# 3        0:15:00             1                       5           10
# 4                            1                       7            9
# 5        0:15:00             2                       8            8
# 6        0:05:00             3                       8            9
# 7        0:05:00     5 or more                       8            9
# 8        0:20:00             3                       5            9
# 9        0:11:30             3                       7            9
# 10       0:15:00             3                       7            7
# 11       0:05:00             1                      10           10
# 12       0:07:00     5 or more                      10           10
# 13       0:06:00             2                       9           10
# 14       0:15:00     5 or more                       9            9
# 15       0:08:00     5 or more                       9           10
# 16       0:08:00             3                       7           10
# 17       0:04:00             4                       8            8
# 18       0:05:00             2                       7            7
# 19       0:20:00             3                       8            8
# 20       0:01:00             4                      10           10
# 21       0:01:30     5 or more                       8            7
# 22                           4                      10           10
# 23       0:10:00             3                       8            9
# 24      00:10:00             3                       8            9
# 25       0:01:30     5 or more                      10            9
# 26       0:08:00             3                      10            8
# 27       0:10:00             4                       8            8
# 28       0:10:00     5 or more                      10           10
# 29       0:04:00             3                       8           10
# 30       0:10:00             3                       8            9
# 31      00:00:00             3                       9            9
# 32       0:10:00             2                       8            7
# 33       0:06:00             2                       8            8
# 34       0:10:00             3                       7           10
# 35       0:07:00             2                       8            8
# 36       0:17:30             3                       7            7
# 37       0:05:00     5 or more                       4           10
# 38       0:06:30             2                      10            9
# 39       0:07:00     5 or more                       8            8
# 40       0:10:00             3                       8            9
# 41       0:07:30             4                       8           10
# 42       0:12:30             3                       8            8
# 43                           2                       6            9
# 44       0:15:00             4                       8            7
# 45       0:15:00             4                       7            9
# 46       0:15:00     5 or more                       3            6
# 47       0:10:00     5 or more                       9            8
# 48       0:10:00     5 or more                       8            7
# 49       0:20:00     5 or more                       7            8
# 50       0:13:30     5 or more                       7            6
# 51       0:08:00     5 or more                       5            7
# 52       0:05:00                                     8            8

# %% [markdown]
# # Formulaic Analysis Of Primary Interview And Survey Data Processed In The Form Of A Connectivity Score
#
# ### Variables and Their Units
# The function uses the following variables:
#
# - **t**: Time taken to travel from home to school in minutes.
# - **a**: Number of bus routes available from home to school (count).
# - **m**: Wait times in minutes.
# - **p**: Peak hour indicator (1 for peak hour, 0 for off-peak).
# - **e**: perceived effectiveness (0-10 interview/survey value).
# - **s**: statisfaction (0-10 interview/survey value).
#
# ### Weights
# Each variable is assigned a weight that reflects its importance in the score calculation.
#
# ### Normalization of Variables
# To ensure that the variables are on a comparable scale, they are normalized. This means converting them to a common scale, typically between 0 and 1, based on assumed maximum realistic values.
#
# ### Raw Score Calculation
# The raw score is calculated using a weighted sum of the normalized variables. This involves multiplying each normalized variable by its respective weight and then summing these values. The sum is then adjusted for peak hours by dividing it by a factor that increases during peak hours.

# %%
def calculate_score(t, a, m, p, e, s):
    # Adjusted weights for each variable
    w1, w2, w3, w4, w5 = 1, 1, 0.2, 0.03, 0.03

    # Normalize the input values (maximum realistic values for normalization)
    max_t = 90     # Max values for times (in minutes)
    max_m = 15       # Max wait times (in minutes)
    max_a = 10                  # Max number of transport options
    max_e = 10                  # Max perceived effectiveness
    max_s = 10                  # Max satisfaction

    t_norm = min(t / max_t, 1)
    m_norm = min(m / max_m, 1)
    a_norm = min(a / max_a, 1)
    e_norm = min (e / max_e, 1)
    s_norm = min (s / max_s, 1)

    # Calculate the raw score
    raw_score = (w1 * t_norm + w2 * (m_norm ) - w3 * a_norm - w4 * e_norm - w5 * s_norm ) / (1 + 0.03 * p)

    # Normalize the raw score to be between 0 and 100
    max_raw_score = w1 + w2 * 2  # Maximum possible raw score
    min_raw_score = -w3  # Minimum possible raw score (negative due to options)

    # Normalize to 0-100
    normalized_score = (raw_score - min_raw_score) / (max_raw_score - min_raw_score) * 100
    normalized_score = max(0, min(normalized_score, 100))  # Ensure it's within the range 0-100

    return normalized_score

# %%
def convert_to_minutes(time_str):
    if pd.isna(time_str):
        return None
    parts = time_str.split(':')
    if len(parts) == 3:
        hours, minutes, seconds = parts
        total_minutes = int(hours) * 60 + int(minutes) + int(seconds) / 60
    elif len(parts) == 2:
        hours, minutes = parts
        total_minutes = int(hours) * 60 + int(minutes)
    else:
        return None  # Handle invalid formats
    return total_minutes

df_ias_by_residence_dgpzone['avg_commute_time_minutes'] = df_ias_by_residence_dgpzone['avg_commute_time'].apply(convert_to_minutes)
df_ias_by_residence_dgpzone['avg_nonpeak_wait_minutes'] = df_ias_by_residence_dgpzone['avg_nonpeak_wait'].apply(convert_to_minutes)
df_ias_by_residence_dgpzone['avg_peak_wait_minutes'] = df_ias_by_residence_dgpzone['avg_peak_wait'].apply(convert_to_minutes)

# %%
# Iterate through the DataFrame and calculate scores for peak and non-peak hours
scores_peak = []
scores_nonpeak = []


for index, row in df_ias_by_residence_dgpzone.iterrows():
    t = float(row['avg_commute_time_minutes'])  # Convert to float
    # Handle non-numeric values in 'num_routes'
    try:
        a = int(row['num_routes'])  # Convert to integer if possible
    except ValueError:
        a = 5  # Or any other suitable default value if conversion fails
    e = int(row['perceived_effectiveness'])  # Convert to integer
    s = int(row['satisfaction'])  # Convert to integer

    # Peak hour score
    m_peak = float(row['avg_peak_wait_minutes'])  # Convert to float
    score_peak = calculate_score(t, a, m_peak, 1, e, s)  # p=1 for peak hour
    scores_peak.append(score_peak)

    # Non-peak hour score
    m_nonpeak = float(row['avg_nonpeak_wait_minutes'])  # Convert to float
    score_nonpeak = calculate_score(t, a, m_nonpeak, 0, e, s)  # p=0 for non-peak hour
    scores_nonpeak.append(score_nonpeak)

# Add the calculated scores to the DataFrame
df_ias_by_residence_dgpzone['score_peak'] = scores_peak
df_ias_by_residence_dgpzone['score_nonpeak'] = scores_nonpeak

df_ias_by_residence_dgpzone
# Out:
#           dgpzone                       transport_modes multi_modal  \
# 0     Bukit Batok                    Mass Rapid Transit         Yes
# 1      Juong East                           Private Car          No
# 2          Bishan       Mass Rapid Transit, Private Car          No
# 3        Tampines                                   Bus          No
# 4        Clementi                           Private Car          No
# 5   Choa Chu Kang                      Bus, Private Car          No
# 6          Tengah                           Private Car          No
# 7   Bukit Panjang                      Bus, Private Car          No
# 8     Bukit Timah                           Private Car          No
# 9     Queenstown                       Bus, Private Car          No
# 10       Clementi                      Bus, Private Car          No
# 11    Jurong West               Bus, Mass Rapid Transit         Yes
# 12    Jurong East                                   Bus          No
# 13  Choa Chu Kang                    Mass Rapid Transit         Yes
# 14    Jurong East                                   Bus          No
# 15    Bukit Batok                                   Bus          No
# 16       Clementi                                   Bus          No
# 17    Jurong West       Mass Rapid Transit, Private Car          No
# 18        Hougang                                   Car          No
# 19       Clementi                           Private Car          No
# 20        Geylang  Bus, Mass Rapid Transit, Private Car          No
# 21  Bukit Panjang               Bus, Mass Rapid Transit          No
# 22        Outram                                    Bus          No
# 23  Bukit Panjang                      Bus, Private Car          No
# 24    Bukit Merah                                   Bus          No
# 25       Clementi                    Mass Rapid Transit          No
# 26      Woodlands  Bus, Mass Rapid Transit, Private Car         Yes
# 27       Clementi                      Bus, Private Car          No
# 28  Bukit Panjang  Bus, Mass Rapid Transit, Private Car          No
# 29    Bukit Merah               Bus, Mass Rapid Transit         Yes
# 30  Bukit Panjang  Bus, Mass Rapid Transit, Private Car         Yes
# 31  Choa Chu Kang                           Private Car          No
# 32     Queenstown               Bus, Mass Rapid Transit         Yes
# 33    Bukit Batok                      Bus, Private Car          No
# 34    Bukit Batok               Bus, Mass Rapid Transit         Yes
# 35    Bukit Batok                      Bus, Private Car          No
# 36    Jurong East                                   Bus          No
# 37       Clementi                                  Walk          No
# 38       Clementi                           Private Car          No
# 39       Clementi                                   Bus          No
# 40       Clementi                           Private Car          No
# 41       Boon Lay               Bus, Mass Rapid Transit         Yes
# 42       Clementi                          Bus, Walking          No
# 43       Clementi                           Private Car          No
# 44       Clementi                      Bus, Private Car         Yes
# 45       Clementi                                   Bus          No
# 46    Jurong East                      Bus, Private Car          No
# 47         Siglap                           Private Car          No
# 48  Marine Parade                           Private Car          No
# 49          Bedok  Bus, Mass Rapid Transit, Private Car          No
# 50       Tampines                                   Bus         Yes
# 51      Toa Payoh                      Bus, Private Car          No
# 52      Pasir Ris                           Private Car          No
#
#    avg_commute_time num_routes                       avg_nonpeak_wait  \
# 0           1:00:00          3                                0:05:00
# 1           0:20:00          3                                0:10:00
# 2           1:00:00          2                                0:05:00
# 3           0:12:30          1                                0:20:00
# 4           0:08:00          2                                0:00:00
# 5           0:15:00          1                                0:15:00
# 6           0:10:00          3                                0:15:00
# 7           0:30:00          3                                0:08:00
# 8           0:15:00          3                                0:10:00
# 9           0:17:30          1                                0:07:00
# 10          0:13:00          2                                0:05:00
# 11          0:30:00          2                                0:05:00
# 12          0:15:00          3                                0:10:00
# 13          0:50:00          2                                0:05:00
# 14          0:20:00          2                                0:15:00
# 15          0:07:00          2                                0:07:30
# 16          0:40:00  5 or more                                0:08:00
# 17          0:30:00          1                                     NA
# 18          0:20:00          2                                0:03:00
# 19          0:10:00          3                                0:15:00
# 20          0:30:00          4                                0:05:00
# 21          0:45:00          2                                0:06:00
# 22          0:10:00          2  depending on the waiting time for bus
# 23          0:45:00          2                                0:10:00
# 24          0:40:00          1                                0:10:00
# 25          0:30:00          1                                0:02:30
# 26          0:30:00          3                                0:05:00
# 27          1:00:00          2                                0:17:30
# 28          0:25:00          2                                0:10:00
# 29          0:40:00          3                                0:07:30
# 30          1:00:00          3                                0:07:30
# 31          0:20:00          2                                0:00:00
# 32          0:30:00          2                                0:07:30
# 33          0:45:00          2                                0:15:00
# 34          0:50:00          2                                0:06:30
# 35          0:45:00          3                                0:10:00
# 36          0:30:00          1                                0:07:30
# 37          0:03:00          1                                0:10:00
# 38          0:10:00          2                                0:04:30
# 39          0:10:00  5 or more                                0:07:00
# 40          0:10:00          1                                0:06:00
# 41          0:30:00          2                                0:07:20
# 42          0:08:30          2                                0:08:30
# 43          0:05:00          2                                0:00:00
# 44          0:35:00          2                                0:10:00
# 45          0:30:00          1                                0:10:00
# 46          0:30:00          3                                0:06:30
# 47          0:15:00          1                                0:05:00
# 48          0:12:30          1                                0:05:00
# 49          1:00:00          3                                0:15:00
# 50          2:07:15          1                                0:07:30
# 51          0:30:00          2                                0:04:00
# 52          0:30:00          1                                0:05:00
#
#    avg_peak_wait num_bus_stops perceived_effectiveness satisfaction  \
# 0        0:03:00             4                       9            9
# 1        0:05:00     5 or more                       8            8
# 2        0:03:00             2                       8            9
# 3        0:15:00             1                       5           10
# 4                            1                       7            9
# 5        0:15:00             2                       8            8
# 6        0:05:00             3                       8            9
# 7        0:05:00     5 or more                       8            9
# 8        0:20:00             3                       5            9
# 9        0:11:30             3                       7            9
# 10       0:15:00             3                       7            7
# 11       0:05:00             1                      10           10
# 12       0:07:00     5 or more                      10           10
# 13       0:06:00             2                       9           10
# 14       0:15:00     5 or more                       9            9
# 15       0:08:00     5 or more                       9           10
# 16       0:08:00             3                       7           10
# 17       0:04:00             4                       8            8
# 18       0:05:00             2                       7            7
# 19       0:20:00             3                       8            8
# 20       0:01:00             4                      10           10
# 21       0:01:30     5 or more                       8            7
# 22                           4                      10           10
# 23       0:10:00             3                       8            9
# 24      00:10:00             3                       8            9
# 25       0:01:30     5 or more                      10            9
# 26       0:08:00             3                      10            8
# 27       0:10:00             4                       8            8
# 28       0:10:00     5 or more                      10           10
# 29       0:04:00             3                       8           10
# 30       0:10:00             3                       8            9
# 31      00:00:00             3                       9            9
# 32       0:10:00             2                       8            7
# 33       0:06:00             2                       8            8
# 34       0:10:00             3                       7           10
# 35       0:07:00             2                       8            8
# 36       0:17:30             3                       7            7
# 37       0:05:00     5 or more                       4           10
# 38       0:06:30             2                      10            9
# 39       0:07:00     5 or more                       8            8
# 40       0:10:00             3                       8            9
# 41       0:07:30             4                       8           10
# 42       0:12:30             3                       8            8
# 43                           2                       6            9
# 44       0:15:00             4                       8            7
# 45       0:15:00             4                       7            9
# 46       0:15:00     5 or more                       3            6
# 47       0:10:00     5 or more                       9            8
# 48       0:10:00     5 or more                       8            7
# 49       0:20:00     5 or more                       7            8
# 50       0:13:30     5 or more                       7            6
# 51       0:08:00     5 or more                       5            7
# 52       0:05:00                                     8            8
#
#     avg_commute_time_minutes  avg_nonpeak_wait_minutes  avg_peak_wait_minutes  \
# 0                      60.00                  5.000000                    3.0
# 1                      20.00                 10.000000                    5.0
# 2                      60.00                  5.000000                    3.0
# 3                      12.50                 20.000000                   15.0
# 4                       8.00                  0.000000                    NaN
# 5                      15.00                 15.000000                   15.0
# 6                      10.00                 15.000000                    5.0
# 7                      30.00                  8.000000                    5.0
# 8                      15.00                 10.000000                   20.0
# 9                      17.50                  7.000000                   11.5
# 10                     13.00                  5.000000                   15.0
# 11                     30.00                  5.000000                    5.0
# 12                     15.00                 10.000000                    7.0
# 13                     50.00                  5.000000                    6.0
# 14                     20.00                 15.000000                   15.0
# 15                      7.00                  7.500000                    8.0
# 16                     40.00                  8.000000                    8.0
# 17                     30.00                       NaN                    4.0
# 18                     20.00                  3.000000                    5.0
# 19                     10.00                 15.000000                   20.0
# 20                     30.00                  5.000000                    1.0
# 21                     45.00                  6.000000                    1.5
# 22                     10.00                       NaN                    NaN
# 23                     45.00                 10.000000                   10.0
# 24                     40.00                 10.000000                   10.0
# 25                     30.00                  2.500000                    1.5
# 26                     30.00                  5.000000                    8.0
# 27                     60.00                 17.500000                   10.0
# 28                     25.00                 10.000000                   10.0
# 29                     40.00                  7.500000                    4.0
# 30                     60.00                  7.500000                   10.0
# 31                     20.00                  0.000000                    0.0
# 32                     30.00                  7.500000                   10.0
# 33                     45.00                 15.000000                    6.0
# 34                     50.00                  6.500000                   10.0
# 35                     45.00                 10.000000                    7.0
# 36                     30.00                  7.500000                   17.5
# 37                      3.00                 10.000000                    5.0
# 38                     10.00                  4.500000                    6.5
# 39                     10.00                  7.000000                    7.0
# 40                     10.00                  6.000000                   10.0
# 41                     30.00                  7.333333                    7.5
# 42                      8.50                  8.500000                   12.5
# 43                      5.00                  0.000000                    NaN
# 44                     35.00                 10.000000                   15.0
# 45                     30.00                 10.000000                   15.0
# 46                     30.00                  6.500000                   15.0
# 47                     15.00                  5.000000                   10.0
# 48                     12.50                  5.000000                   10.0
# 49                     60.00                 15.000000                   20.0
# 50                    127.25                  7.500000                   13.5
# 51                     30.00                  4.000000                    8.0
# 52                     30.00                  5.000000                    5.0
#
#     score_peak  score_nonpeak
# 0    29.085761      33.937500
# 1    19.828749      30.652778
# 2    29.783576      34.656250
# 3    38.831580      39.809028
# 4     0.000000       6.277778
# 5    39.583333      40.583333
# 6    16.366640      37.503472
# 7    23.108819      29.864583
# 8    38.551780      29.104167
# 9    33.346818      24.784722
# 10   38.484358      18.618056
# 11   23.442557      23.958333
# 12   21.824434      28.541667
# 13   32.298409      30.996528
# 14   40.480043      41.506944
# 15   21.848031      21.274306
# 16   31.334277      32.086806
# 17   22.390777       0.000000
# 18   20.617584      16.881944
# 19   36.684196      37.597222
# 20   14.138350      22.708333
# 21   21.875000      31.718750
# 22    0.000000       0.000000
# 23   38.885518      39.864583
# 24   37.806769      38.753472
# 25   17.061084      19.468750
# 26   29.085761      23.520833
# 27   44.033172      55.583333
# 28   31.870280      32.638889
# 29   24.366235      32.201389
# 30   43.335356      39.239583
# 31   10.140237      10.256944
# 32   34.010922      29.635417
# 33   30.885922      50.375000
# 34   40.571063      34.309028
# 35   32.301780      39.333333
# 36   44.822006      30.354167
# 37   15.493528      26.187500
# 38   19.825378      16.065972
# 39   19.289374      19.680556
# 40   27.693501      20.003472
# 41   28.681230      29.006944
# 42   31.728695      24.159722
# 43    0.000000       5.329861
# 44   45.809736      36.579861
# 45   44.639968      35.375000
# 46   44.063511      27.489583
# 47   29.379045      19.656250
# 48   28.718312      18.975694
# 49   53.630663      55.052083
# 50   62.105583      51.281250
# 51   30.238673      22.625000
# 52   24.413430      24.958333

# %% [markdown]
# # Plotting And Mapping The Connectivity Score Onto A Map Visualized Through A Heatmap

# %%
import requests

url = "https://www.onemap.gov.sg/api/public/popapi/getAllPlanningarea?year=2019"

headers = {"Authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..s7s2FJAgaifFeLO1qEQop05Gwh6C1Dk3tcmCpO-UQ-s"}

response = requests.request("GET", url, headers=headers)

print(response.status_code)

# Save response into file
with open('planning_areas.json', 'w') as f:
    f.write(response.text)
# Out:
# 200

# %%
import json

# Function to convert the input data to the desired format
def convert_to_feature_collection(data):
    feature_collection = {
        "type": "FeatureCollection",
        "features": []
    }

    for index, result in enumerate(data["SearchResults"]):
        feature = {
            "type": "Feature",
            "properties": {
                "name": result["pln_area_n"].capitalize(),
                "index": index
            },
            "geometry": json.loads(result["geojson"])
        }
        feature_collection["features"].append(feature)

    return feature_collection

# Convert the input data
output_data = convert_to_feature_collection(json.loads(response.text))

# Print the output data
dgp_zone_map = json.dumps(output_data, indent=2)

# %%
import json

def capitalize_words(text):
  return ' '.join([word.capitalize() for word in text.split()])

# 'dgp_zone_map' is currently a string, convert it back to a dictionary
dgp_zone_map_dict = json.loads(dgp_zone_map)

# Iterate over the features in the FeatureCollection
for feature in dgp_zone_map_dict['features']:
    # Capitalize the 'name' property of each feature
    feature['properties']['name'] = capitalize_words(feature['properties']['name'])

# Convert the modified dictionary back to a JSON string
dgp_zone_map = json.dumps(dgp_zone_map_dict, indent=2)

# %%
# Load the GeoJSON data into a GeoDataFrame
gdf = gpd.read_file(dgp_zone_map)

# Calculate average scores for each DGP zone
average_scores_peak = df_ias_by_residence_dgpzone.groupby('dgpzone')['score_peak'].mean().reset_index()
average_scores_nonpeak = df_ias_by_residence_dgpzone.groupby('dgpzone')['score_nonpeak'].mean().reset_index()

# Merge the average scores with the GeoDataFrame
gdf_peak = gdf.merge(average_scores_peak, left_on='name', right_on='dgpzone')
gdf_nonpeak = gdf.merge(average_scores_nonpeak, left_on='name', right_on='dgpzone')

# %%
# Get a list of all DGP zones in the GeoDataFrame
all_dgp_zones = gdf['name'].unique()

# Get a list of DGP zones with data
dgp_zones_with_data_peak = average_scores_peak['dgpzone'].unique()
dgp_zones_with_data_nonpeak = average_scores_nonpeak['dgpzone'].unique()

# Find DGP zones with no data
dgp_zones_without_data_peak = [zone for zone in all_dgp_zones if zone not in dgp_zones_with_data_peak]
dgp_zones_without_data_nonpeak = [zone for zone in all_dgp_zones if zone not in dgp_zones_with_data_nonpeak]

# Create DataFrames for DGP zones with no data and a score of 100
new_data_peak = pd.DataFrame({'dgpzone': dgp_zones_without_data_peak, 'score_peak': [100] * len(dgp_zones_without_data_peak)})
new_data_nonpeak = pd.DataFrame({'dgpzone': dgp_zones_without_data_nonpeak, 'score_nonpeak': [100] * len(dgp_zones_without_data_nonpeak)})

# Append the new data to the average scores DataFrames
average_scores_peak = pd.concat([average_scores_peak, new_data_peak], ignore_index=True)
average_scores_nonpeak = pd.concat([average_scores_nonpeak, new_data_nonpeak], ignore_index=True)

# Re-merge the average scores with the GeoDataFrame
gdf_peak = gdf.merge(average_scores_peak, left_on='name', right_on='dgpzone')
gdf_nonpeak = gdf.merge(average_scores_nonpeak, left_on='name', right_on='dgpzone')

# %%
# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(70, 20))

# Plot peak hour heatmap
gdf_peak.plot(column='score_peak', cmap='hot', linewidth=0.8, ax=ax1, edgecolor='k', legend=True, missing_kwds={'color': 'black'})
ax1.set_title('Average Peak Hour Connectivity Score (By Student Residence DGP Zone)')

# Plot non-peak hour heatmap
gdf_nonpeak.plot(column='score_nonpeak', cmap='hot', linewidth=0.8, ax=ax2, edgecolor='k', legend=True, missing_kwds={'color': 'black'})
ax2.set_title('Average Non-Peak Hour Connectivity Score (by Student Residence DGP Zone)')

# Label DGP zones with black background for better visibility
for idx, row in gdf_peak.iterrows():
    ax1.annotate(text=row['name'], xy=row['geometry'].centroid.coords[0], ha='center', va='center', color='white',
                 bbox=dict(facecolor='black', alpha=0.7, ))
for idx, row in gdf_nonpeak.iterrows():
    ax2.annotate(text=row['name'], xy=row['geometry'].centroid.coords[0], ha='center', va='center', color='white',
                 bbox=dict(facecolor='black', alpha=0.7, ))

plt.subplots_adjust(wspace=0, hspace=0)
plt.show()
